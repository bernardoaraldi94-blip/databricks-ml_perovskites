# %%
import pandas as pd

df = pd.DataFrame({
    "composition": ["ABO3", "A2BO4"],
    "bandgap": [2.1, 1.8]
})

df

# %%
# %sql 
select * from ml_perovskites.atom_props

# %%
# %sql 
select * from ml_perovskites.db_ml
where reaction_type = "Photocatalysis"
